# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, Trainer, TrainingArguments, pipeline
from datasets import Dataset

# %%
csv_path = "SQuAD.csv"
df = pd.read_csv(csv_path)

# %%
df["answers"] = df.apply(lambda x: {"text": [x["text"]], "answer_start": [x["answer_start"]]}, axis=1)
df = df.drop(columns=["#"], errors="ignore")

# %%
dataset = Dataset.from_pandas(df)

# %%
dataset = dataset.train_test_split(test_size=0.2, seed=42)
train_dataset = dataset["train"]
val_dataset = dataset["test"]

# %%
model_name = "distilbert-base-uncased"  # Small & efficient BERT variant
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def preprocess_function(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        truncation="only_second",
        max_length=384,
        stride=128,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )
    sample_mapping = inputs.pop("overflow_to_sample_mapping")
    offset_mapping = inputs.pop("offset_mapping")

    start_positions = []
    end_positions = []

    for i, offsets in enumerate(offset_mapping):
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]

        # Check if there are no answers or if the answer text is invalid.
        # An answer is considered invalid if its 'answer_start' list is empty,
        # or if the first element of 'text' is None, or if it's an empty string.
        if len(answers["answer_start"]) == 0 or answers["text"][0] is None or (isinstance(answers["text"][0], str) and len(answers["text"][0]) == 0):
            start_positions.append(0)
            end_positions.append(0)
        else:
            start_char = answers["answer_start"][0]
            answer_text = answers["text"][0]

            # Ensure answer_text is a string before calling len()
            if not isinstance(answer_text, str):
                answer_text = str(answer_text)

            end_char = start_char + len(answer_text)
            sequence_ids = inputs.sequence_ids(i)

            token_start_index = 0
            while sequence_ids[token_start_index] != 1:
                token_start_index += 1
            token_end_index = len(inputs["input_ids"][i]) - 1
            while sequence_ids[token_end_index] != 1:
                token_end_index -= 1

            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                start_positions.append(0)
                end_positions.append(0)
            else:
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                start_positions.append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                end_positions.append(token_end_index + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# 5️⃣ Tokenize
tokenized_train = train_dataset.map(preprocess_function, batched=True, remove_columns=train_dataset.column_names)
tokenized_val = val_dataset.map(preprocess_function, batched=True, remove_columns=val_dataset.column_names)
# Out:
# Map:   0%|          | 0/69456 [00:00<?, ? examples/s]
# Map:   0%|          | 0/17365 [00:00<?, ? examples/s]

# %%
# 6️⃣ Training Configuration
# !pip install --upgrade transformers
training_args = TrainingArguments(
    output_dir="./faq_csv_model",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    num_train_epochs=2,
    weight_decay=0.01,
    logging_dir="./logs",
)
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    tokenizer=tokenizer,
)

trainer.train()

trainer.save_model("./faq_csv_model")
# Out:
# /tmp/ipython-input-3325889632.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: steephanrajsanjay (steephanrajsanjay-coimbatore-institute-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/content/wandb/run-20251110_095432-s8myk91r</code>
# Syncing run <strong><a href='https://wandb.ai/steephanrajsanjay-coimbatore-institute-of-technology/huggingface/runs/s8myk91r' target="_blank">cool-bird-1</a></strong> to <a href='https://wandb.ai/steephanrajsanjay-coimbatore-institute-of-technology/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/steephanrajsanjay-coimbatore-institute-of-technology/huggingface' target="_blank">https://wandb.ai/steephanrajsanjay-coimbatore-institute-of-technology/huggingface</a>
#  View run at <a href='https://wandb.ai/steephanrajsanjay-coimbatore-institute-of-technology/huggingface/runs/s8myk91r' target="_blank">https://wandb.ai/steephanrajsanjay-coimbatore-institute-of-technology/huggingface/runs/s8myk91r</a>
#     <div>
#
#       <progress value='17552' max='17552' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [17552/17552 1:36:22, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.236000</td>
#       <td>1.107349</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.941200</td>
#       <td>1.089826</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
qa_pipeline = pipeline("question-answering", model="./faq_csv_model", tokenizer=tokenizer)
# Out:
# Device set to use cuda:0

# %%
context = """

Evaluation metrics are quantitative measures used to assess the performance and effectiveness of statistical or machine learning models, providing insights into how well a model is performing and aiding in the comparison of different models or algorithms.
 These metrics are crucial for evaluating predictive ability, generalization capability, and overall quality, ensuring models are reliable and capable of making accurate predictions on new, unseen data.
 They are essential for guiding model improvements and determining whether a model is ready for deployment

For classification tasks, common evaluation metrics include accuracy, precision, recall (also known as sensitivity), F1 score, specificity, and the area under the ROC curve (AUC-ROC).
 Accuracy measures the percentage of correctly predicted labels out of total predictions, but it can be misleading in imbalanced datasets.
 Precision indicates the proportion of correctly predicted positive results among all predicted positives, which is vital when minimizing false positives is critical, such as in spam detection or medical diagnostics.
 Recall measures the model's ability to identify all actual positive instances, making it essential in scenarios where missing true positives has severe consequences, like disease detection.
 The F1 score, the harmonic mean of precision and recall, provides a balanced measure, particularly useful in imbalanced datasets


 """

question = "definition of the Classification Metrics?"

result = qa_pipeline(question=question, context=context)
print(result)
# Out:
# {'score': 0.013782382942736149, 'start': 277, 'end': 366, 'answer': 'crucial for evaluating predictive ability, generalization capability, and overall quality'}

# %%
from google.colab import files
# !zip -r faq_csv_model.zip faq_csv_model
files.download("faq_csv_model.zip")
# Out:
#   adding: faq_csv_model/ (stored 0%)
#   adding: faq_csv_model/checkpoint-6000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-6000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-6000/trainer_state.json (deflated 68%)
#   adding: faq_csv_model/checkpoint-6000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-6000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-6000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-6000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-6000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-6000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-6000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-6000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-6000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-17500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-17500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-17500/trainer_state.json (deflated 74%)
#   adding: faq_csv_model/checkpoint-17500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-17500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-17500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-17500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-17500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-17500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-17500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-17500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-17500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-15500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-15500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-15500/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-15500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-15500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-15500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-15500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-15500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-15500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-15500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-15500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-15500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-3500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-3500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-3500/trainer_state.json (deflated 65%)
#   adding: faq_csv_model/checkpoint-3500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-3500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-3500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-3500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-3500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-3500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-3500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-3500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-3500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-12000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-12000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-12000/trainer_state.json (deflated 72%)
#   adding: faq_csv_model/checkpoint-12000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-12000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-12000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-12000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-12000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-12000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-12000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-12000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-12000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-14500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-14500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-14500/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-14500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-14500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-14500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-14500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-14500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-14500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-14500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-14500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-14500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-11000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-11000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-11000/trainer_state.json (deflated 72%)
#   adding: faq_csv_model/checkpoint-11000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-11000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-11000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-11000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-11000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-11000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-11000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-11000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-11000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-5500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-5500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-5500/trainer_state.json (deflated 68%)
#   adding: faq_csv_model/checkpoint-5500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-5500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-5500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-5500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-5500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-5500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-5500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-5500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-5500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-4500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-4500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-4500/trainer_state.json (deflated 66%)
#   adding: faq_csv_model/checkpoint-4500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-4500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-4500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-4500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-4500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-4500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-4500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-4500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-4500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-15000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-15000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-15000/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-15000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-15000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-15000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-15000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-15000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-15000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-15000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-15000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-15000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-6500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-6500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-6500/trainer_state.json (deflated 69%)
#   adding: faq_csv_model/checkpoint-6500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-6500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-6500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-6500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-6500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-6500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-6500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-6500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-6500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-500/trainer_state.json (deflated 55%)
#   adding: faq_csv_model/checkpoint-500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-500/optimizer.pt (deflated 16%)
#   adding: faq_csv_model/checkpoint-500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-2000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-2000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-2000/trainer_state.json (deflated 61%)
#   adding: faq_csv_model/checkpoint-2000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-2000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-2000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-2000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-2000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-2000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-2000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-2000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-2000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-2500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-2500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-2500/trainer_state.json (deflated 63%)
#   adding: faq_csv_model/checkpoint-2500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-2500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-2500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-2500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-2500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-2500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-2500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-2500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-2500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-9000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-9000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-9000/trainer_state.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-9000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-9000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-9000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-9000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-9000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-9000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-9000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-9000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-9000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-8500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-8500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-8500/trainer_state.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-8500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-8500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-8500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-8500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-8500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-8500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-8500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-8500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-8500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-16000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-16000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-16000/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-16000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-16000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-16000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-16000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-16000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-16000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-16000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-16000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-16000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-17000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-17000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-17000/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-17000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-17000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-17000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-17000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-17000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-17000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-17000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-17000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-17000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-16500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-16500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-16500/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-16500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-16500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-16500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-16500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-16500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-16500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-16500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-16500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-16500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-14000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-14000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-14000/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-14000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-14000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-14000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-14000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-14000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-14000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-14000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-14000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-14000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-13500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-13500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-13500/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-13500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-13500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-13500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-13500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-13500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-13500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-13500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-13500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-13500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-13000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-13000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-13000/trainer_state.json (deflated 72%)
#   adding: faq_csv_model/checkpoint-13000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-13000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-13000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-13000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-13000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-13000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-13000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-13000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-13000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-7000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-7000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-7000/trainer_state.json (deflated 70%)
#   adding: faq_csv_model/checkpoint-7000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-7000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-7000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-7000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-7000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-7000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-7000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-7000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-7000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-10000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-10000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-10000/trainer_state.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-10000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-10000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-10000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-10000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-10000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-10000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-10000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-10000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-10000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-1500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-1500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-1500/trainer_state.json (deflated 59%)
#   adding: faq_csv_model/checkpoint-1500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-1500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-1500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-1500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-1500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-1500/optimizer.pt (deflated 14%)
#   adding: faq_csv_model/checkpoint-1500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-1500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-1500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-3000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-3000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-3000/trainer_state.json (deflated 64%)
#   adding: faq_csv_model/checkpoint-3000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-3000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-3000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-3000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-3000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-3000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-3000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-3000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-3000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-9500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-9500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-9500/trainer_state.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-9500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-9500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-9500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-9500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-9500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-9500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-9500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-9500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-9500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-8000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-8000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-8000/trainer_state.json (deflated 70%)
#   adding: faq_csv_model/checkpoint-8000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-8000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-8000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-8000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-8000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-8000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-8000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-8000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-8000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-10500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-10500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-10500/trainer_state.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-10500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-10500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-10500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-10500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-10500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-10500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-10500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-10500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-10500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-7500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-7500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-7500/trainer_state.json (deflated 70%)
#   adding: faq_csv_model/checkpoint-7500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-7500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-7500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-7500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-7500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-7500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-7500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-7500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-7500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-11500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-11500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-11500/trainer_state.json (deflated 72%)
#   adding: faq_csv_model/checkpoint-11500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-11500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-11500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-11500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-11500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-11500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-11500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-11500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-11500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-5000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-5000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-5000/trainer_state.json (deflated 67%)
#   adding: faq_csv_model/checkpoint-5000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-5000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-5000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-5000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-5000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-5000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-5000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-5000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-5000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-4000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-4000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-4000/trainer_state.json (deflated 66%)
#   adding: faq_csv_model/checkpoint-4000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-4000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-4000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-4000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-4000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-4000/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-4000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-4000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-4000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-1000/ (stored 0%)
#   adding: faq_csv_model/checkpoint-1000/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-1000/trainer_state.json (deflated 57%)
#   adding: faq_csv_model/checkpoint-1000/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-1000/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-1000/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-1000/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-1000/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-1000/optimizer.pt (deflated 14%)
#   adding: faq_csv_model/checkpoint-1000/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-1000/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-1000/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-17552/ (stored 0%)
#   adding: faq_csv_model/checkpoint-17552/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-17552/trainer_state.json (deflated 73%)
#   adding: faq_csv_model/checkpoint-17552/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-17552/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-17552/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-17552/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-17552/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-17552/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-17552/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-17552/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-17552/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/checkpoint-12500/ (stored 0%)
#   adding: faq_csv_model/checkpoint-12500/rng_state.pth (deflated 26%)
#   adding: faq_csv_model/checkpoint-12500/trainer_state.json (deflated 72%)
#   adding: faq_csv_model/checkpoint-12500/training_args.bin (deflated 53%)
#   adding: faq_csv_model/checkpoint-12500/config.json (deflated 43%)
#   adding: faq_csv_model/checkpoint-12500/special_tokens_map.json (deflated 42%)
#   adding: faq_csv_model/checkpoint-12500/model.safetensors (deflated 8%)
#   adding: faq_csv_model/checkpoint-12500/vocab.txt (deflated 53%)
#   adding: faq_csv_model/checkpoint-12500/optimizer.pt (deflated 13%)
#   adding: faq_csv_model/checkpoint-12500/scheduler.pt (deflated 61%)
#   adding: faq_csv_model/checkpoint-12500/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/checkpoint-12500/tokenizer.json (deflated 71%)
#   adding: faq_csv_model/tokenizer_config.json (deflated 75%)
#   adding: faq_csv_model/tokenizer.json (deflated 71%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp -r /content/faq_csv_model /content/drive/MyDrive/
# Out:
# Mounted at /content/drive
# cp: cannot stat '/content/faq_csv_model': No such file or directory

# %%
import os, shutil

# %%
base_dir = "/content/drive/MyDrive/faq_csv_model"
latest_checkpoint = "checkpoint-17552"
final_dest = "/content/drive/MyDrive/faq_folder/final_model"

# %%
src = os.path.join(base_dir, latest_checkpoint)
shutil.copytree(src, final_dest)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-264302969.py in <cell line: 0>()
#       1 src = os.path.join(base_dir, latest_checkpoint)
# ----> 2 shutil.copytree(src, final_dest)
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     596     """
#     597     sys.audit("shutil.copytree", src, dst)
# --> 598     with os.scandir(src) as itr:
#     599         entries = list(itr)
#     600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/faq_csv_model/checkpoint-17552'
